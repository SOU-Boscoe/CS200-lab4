# %% [markdown]
# # CS200 Lab 4: Python Lists
#
# This lab gives you practice with Python lists and a little review of functions. These are all from chapter 6, Lists, in your Zybook.
#
# Topics:
# - looping through strings with `for ch in word:`
# - creating lists
# - indexing and slicing
# - `append()`
# - checking membership with `in`
# - `pop()`
# - sorting
# - `len()`
# - writing a few simple functions
#
# There are **20 questions**. The last question is a larger TODO program.

# %% [markdown]
# ## Question 1: Loop through a string
#
# Write code that prints each character in the string `"weather"` on its own line.

# %%
word = "weather"

# TODO: print each character in word on its own line

# %% [markdown]
# ## Question 2: Count letters manually
#
# Use a `for` loop to count how many times the letter `e` appears in `word`.
#
# Do not use `.count()` for this question.

# %%
word = "temperature"
count = 0

# TODO: update count each time you see an "e"

print(count)

# %% [markdown]
# ## Question 3: Build a list from a string
#
# Create an empty list called `letters`. Loop through the string `"humidity"` and append each character to `letters`.

# %%
word = "humidity"
letters = []

# TODO: append each character to letters

print(letters)

# %% [markdown]
# ## Question 4: Create a list
#
# Create a list called `weather_variables` containing these strings:
#
# `"temperature"`, `"humidity"`, `"wind speed"`, `"precipitation"`
#
# Then print the list.

# %%
# TODO: create the list

# TODO: print the list

# %% [markdown]
# ## Question 5: Indexing
#
# Using the list below, print:
#
# 1. the first item
# 2. the last item
# 3. the item at index 2

# %%
friends = ["Ana", "Cindy", "Dev", "Mina", "Sam"]

# TODO: print the first item

# TODO: print the last item

# TODO: print the item at index 2

# %% [markdown]
# ## Question 6: Membership with `in`
#
# Use an `if` statement to check whether `"Cindy"` is in the `friends` list.
#
# Print a friendly message if she is in the list. Print a different message if she is not.

# %%
friends = ["Ana", "Cindy", "Dev", "Mina", "Sam"]

# TODO: check whether "Cindy" is in friends

# %% [markdown]
# ## Question 7: Append
#
# Start with the list below. Add two more friends using `append()`.
#
# Then print the updated list.

# %%
friends = ["Ana", "Cindy", "Dev"]

# TODO: append two more names

print(friends)

# %% [markdown]
# ## Question 8: Pop
#
# Use `pop()` to remove the last item from the list.
#
# Store the removed value in a variable called `removed_friend`, then print both the removed friend and the updated list.

# %%
friends = ["Ana", "Cindy", "Dev", "Mina", "Sam"]

# TODO: pop the last item and save it in removed_friend

# TODO: print removed_friend

# TODO: print friends

# %% [markdown]
# ## Question 9: Pop by index
#
# Use `pop()` with an index to remove `"Cindy"` from the list.
#
# Then print the updated list.

# %%
friends = ["Ana", "Cindy", "Dev", "Mina", "Sam"]

# TODO: remove "Cindy" using pop(index)

print(friends)

# %% [markdown]
# ## Question 10: Length
#
# Use `len()` to print how many numbers are in the list.
#
# Then print a sentence like:
#
# `There are 6 PM2.5 readings.`

# %%
pm25 = [12.5, 18.2, 9.7, 24.1, 31.0, 15.8]

# TODO: use len() and print a sentence

# %% [markdown]
# ## Question 11: Slices
#
# Using the list below, print:
#
# 1. the first three readings
# 2. the last three readings
# 3. every other reading

# %%
pm25 = [12.5, 18.2, 9.7, 24.1, 31.0, 15.8, 20.3, 17.4]

# TODO: first three

# TODO: last three

# TODO: every other reading

# %% [markdown]
# ## Question 12: Sorting numbers
#
# Sort the list of PM2.5 readings from lowest to highest.
#
# Then print the sorted list.

# %%
pm25 = [12.5, 18.2, 9.7, 24.1, 31.0, 15.8]

# TODO: sort the list

print(pm25)

# %% [markdown]
# ## Question 13: Sorting strings
#
# Sort the list of city names alphabetically.
#
# Then print the sorted list.

# %%
cities = ["Medford", "Ashland", "Portland", "Eugene", "Bend"]

# TODO: sort cities

print(cities)

# %% [markdown]
# ## Question 14: Find values above a threshold
#
# Create an empty list called `high_readings`.
#
# Loop through `pm25` and append any reading greater than `20` to `high_readings`.
#
# Print `high_readings` at the end.

# %%
pm25 = [12.5, 18.2, 9.7, 24.1, 31.0, 15.8, 20.3, 17.4]
high_readings = []

# TODO: append readings greater than 20

print(high_readings)

# %% [markdown]
# ## Question 15: Pair weather variables and readings
#
# The two lists below match by position. For example, `variables[0]` goes with `readings[0]`.
#
# Use a loop with `range(len(variables))` to print sentences like:
#
# `temperature: 72`

# %%
variables = ["temperature", "humidity", "wind speed", "precipitation"]
readings = [72, 58, 12, 0.3]

# TODO: loop through the indexes and print each variable with its reading

# %% [markdown]
# ## Question 16: Simple average
#
# Use a loop to calculate the average of the PM2.5 readings.
#
# You may use `len()`, but do not use `sum()` for this question.

# %%
pm25 = [12.5, 18.2, 9.7, 24.1, 31.0, 15.8]
total = 0

# TODO: add each reading to total

# TODO: calculate and print the average

# %% [markdown]
# ## Question 17: Function practice — count high readings
#
# Write a function called `count_high_readings(readings, threshold)`.
#
# The function should return how many readings are greater than `threshold`.
#
# Then call your function using the PM2.5 list below.

# %%
def count_high_readings(readings, threshold):
    # TODO: count how many readings are greater than threshold
    pass

pm25 = [12.5, 18.2, 9.7, 24.1, 31.0, 15.8]

# TODO: call the function and print the result

# %% [markdown]
# ## Question 18: Function practice — get first and last
#
# Write a function called `first_and_last(items)`.
#
# The function should return a list containing only the first item and the last item.
#
# Example:
#
# ```python
# first_and_last([10, 20, 30, 40])
# ```
#
# should return:
#
# ```python
# [10, 40]
# ```

# %%
def first_and_last(items):
    # TODO: return a list with the first and last item
    pass

numbers = [10, 20, 30, 40]

# TODO: call the function and print the result

# %% [markdown]
# ## Question 19: Function practice — clean a list
#
# Write a function called `remove_negative_numbers(numbers)`.
#
# The function should return a new list containing only numbers that are greater than or equal to `0`.

# %%
def remove_negative_numbers(numbers):
    # TODO: create a new list with no negative numbers
    pass

readings = [12, -1, 18, 0, -5, 22]

# TODO: call the function and print the cleaned list

# %% [markdown]
# ## Question 20: TODO program — Weather reading tracker
#
# Write a small program that helps track PM2.5 readings for a city.
#
# Your program should:
#
# 1. Start with an empty list called `readings`.
# 2. Use `append()` to add at least five PM2.5 readings.
# 3. Print the full list.
# 4. Print how many readings are in the list using `len()`.
# 5. Sort the readings from lowest to highest.
# 6. Print the lowest reading and highest reading.
# 7. Create a new list called `unhealthy_readings` containing readings greater than `35`.
# 8. Print a final summary sentence.
#
# Example summary sentence:
#
# `Medford had 2 readings above 35.`
#
# Optional challenge: put part of your program into a function.

# %%
city = "Medford"
readings = []

# TODO: add at least five PM2.5 readings using append()

# TODO: print the full list

# TODO: print the number of readings

# TODO: sort the readings

# TODO: print the lowest and highest reading

unhealthy_readings = []

# TODO: add readings greater than 35 to unhealthy_readings

# TODO: print a final summary sentence

# %% [markdown]
# In the cell below, write a reflection about Chapter 6 in your Zybook. What was one challenging section? What part of the chapter did you find might be useful in your other classes?
